# %% [markdown]
# Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
import sklearn

# %% [markdown]
# Data preparation

# %%
df = pd.read_csv("D:\Course\Machine Learning\Jadi\Codes\Machine_Learning\Datastes\student-por.csv") 
df = df[["G1", "G2", "G3"]]
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df = pd.read_csv("D:\Course\Machine Learning\Jadi\Codes\Machine_Learning\Datastes\student-por.csv")
#       2 df = df[["G1", "G2", "G3"]]
#       3 df.head()
#
# ...

# %%
df.describe()
# Out:
#                G1          G2          G3
# count  649.000000  649.000000  649.000000
# mean    11.399076   11.570108   11.906009
# std      2.745265    2.913639    3.230656
# min      0.000000    0.000000    0.000000
# 25%     10.000000   10.000000   10.000000
# 50%     11.000000   11.000000   12.000000
# 75%     13.000000   13.000000   14.000000
# max     19.000000   19.000000   19.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   G1      649 non-null    int64
#  1   G2      649 non-null    int64
#  2   G3      649 non-null    int64
# dtypes: int64(3)
# memory usage: 15.3 KB

# %%
df.hist(figsize=[20,20], bins=10)
plt.show()

# %%
plt.scatter(df.G1, df.G3, color = 'blue')
plt.show()

# %%
predict = "G3"

x = np.array(df.drop("G3", axis=1))
y = np.array(df[predict])

x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(x, y, test_size=0.1)

linear = linear_model.LinearRegression()

linear.fit(x_train, y_train)

accuracy = linear.score(x_test,y_test)
print("Model Accuracy: ", accuracy)

print("Coefficient: ", linear.coef_) #We have a 5 dimensional space here so we have 5 Coefficients! (our line starting position depending on 5 axis )
print("Intercept: ", linear.intercept_) # y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 predict = "G3"
# ----> 3 x = np.array(df.drop("G3", axis=1))
#       4 y = np.array(df[predict])
#       6 x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(x, y, test_size=0.1)
#
# NameError: name 'np' is not defined
